# %%
# the images get downloaded in folder let's preprocess the images and save them in some another folder.
# resize the images. 
from dataclasses import dataclass
from pathlib import Path

# %%
@dataclass(frozen=True)
class DownloadDataConfig:
    data_directory: Path
    source_gdrive_url: str
    gdrive_api_key : str
    download_image_folder : Path


@dataclass(frozen=True)
class PreprocessDataConfig:
    download_image_folder:Path
    processed_image_folder:Path

@dataclass(frozen=True)
class PrepareBlurImageConfig:
    processed_image_folder:Path
    blur_image_folder:Path

# %%
from autoencoder.constants import filepath
from autoencoder import logger
from autoencoder.utils.util_functions import read_yaml, create_dir

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = filepath.CONFIG_FILE_PATH,
        param_filepath = filepath.PARAMS_FILE_PATH,
        secret_filepath = filepath.SECRET_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(param_filepath)
        self.secret = read_yaml(secret_filepath)
        # Creating Root folder called artifacts
        create_dir([self.config.root])


    def get_download_data_config(self) -> DownloadDataConfig:
        logger.info(f'getting download data configuration')
        config = self.config.data_paths

        logger.info(f'Creating dataset and orignal_image folder Inside artifacts folder')
        create_dir([config.data_directory, config.download_image_folder])


        download_data_config = DownloadDataConfig(
            data_directory = config.data_directory,
            source_gdrive_url = config.source_gdrive_url,
            gdrive_api_key = config.gdrive_api_key,
            download_image_folder = config.download_image_folder
        )

        return download_data_config
    

    def get_preprocess_data_config(self) -> DownloadDataConfig:
        logger.info(f'getting download data configuration')
        config = self.config.data_paths
        logger.info(f'Creating Data Directory Folder')
        create_dir([config.processed_image_folder])

        preprocess_data_config = PreprocessDataConfig(
            download_image_folder = config.download_image_folder,
            processed_image_folder=config.processed_image_folder
        )

        return preprocess_data_config
    
    
    def get_blurimage_data_config(self) -> PrepareBlurImageConfig:
        logger.info(f'getting download data configuration')
        config = self.config.data_paths
        logger.info(f'Creating Data Directory Folder')
        create_dir([config.blur_image_folder])

        blurimage_data_config = PrepareBlurImageConfig(
            processed_image_folder=config.processed_image_folder,
            blur_image_folder= config.blur_image_folder
        )

        return blurimage_data_config

# %%
import requests
import gdown
import os
import cv2
from keras.preprocessing import image
from PIL import Image
from concurrent.futures import ThreadPoolExecutor

# %%
class DataIngestionPreparation:
    def __init__(self, download_config: DownloadDataConfig,
                  preprocess_config: PreprocessDataConfig,
                  blurimage_config : PrepareBlurImageConfig):
        self.download_config = download_config
        self.preprocess_config = preprocess_config
        self.blurimage_config = blurimage_config


    # def download_data(self) ->str:
    #     try:
    #         source_url = self.download_config.source_gdrive_url
    #         folder_id = source_url.split("/")[-1]
    #         folder_id = folder_id.split("?")[0]

    #         api_token = self.download_config.gdrive_api_key
    #         api_url = f"https://www.googleapis.com/drive/v3/files?q='{folder_id}'+in+parents&key={api_token}"
    #         logger.info(f"Getting Response from Gdrive api _url : {api_url}")
    #         response = requests.get(api_url)
    #         logger.info(f'response : {response.status_code}')
    #         if response.status_code==200:
    #             logger.info("Response 200 OK")
    #             files = response.json().get('files', [])
    #             logger.info(f'Downloading files in folder : {self.download_config.download_image_folder}')
    #             for file in files:
    #                 file_id = file['id']
    #                 file_name = file['name']
    #                 download_url = f'https://drive.google.com/uc?id={file_id}'
                    
    #                 # Download the file using gdown
    #                 gdown.download(download_url, os.path.join(self.download_config.download_image_folder, file_name), quiet=False)
    #             logger.info("**** Images Downloaded Ready for Preprocess ****")
    #         else:
    #             logger.info("Unable to Downlaod the data")

    #     except Exception as e:
    #         raise e



    def download_file(self,file_info, destination_folder):
        file_id = file_info['id']
        file_name = file_info['name']
        download_url = f'https://drive.google.com/uc?id={file_id}'
        output_path = os.path.join(destination_folder, file_name)
        gdown.download(download_url, output_path, quiet=False)

    def download_files_in_parallel(self):
        try:
            source_url = self.download_config.source_gdrive_url
            folder_id = source_url.split("/")[-1]
            folder_id = folder_id.split("?")[0]

            api_token = self.download_config.gdrive_api_key
            api_url = f"https://www.googleapis.com/drive/v3/files?q='{folder_id}'+in+parents&key={api_token}"
            response = requests.get(api_url)
            logger.info(f'response : {response.status_code}')
            if response.status_code == 200:
                files = response.json().get('files', [])
                # Use ThreadPoolExecutor to download files in parallel
                with ThreadPoolExecutor(max_workers=32) as executor:
                    executor.map(lambda file: self.download_file(file, self.download_config.download_image_folder), files)
            else:
                print("Failed to retrieve folder content.")
                print(f"Error: {response.status_code}, {response.text}")
        except Exception as e:
            raise e


    def preprocess_data(self) ->str:
        try:
            source_folder = self.preprocess_config.download_image_folder
            destination_folder = self.preprocess_config.processed_image_folder
            image_paths = [f for f in os.listdir(source_folder) if os.path.isfile(os.path.join(source_folder, f))]
            logger.info('Resizing the Images to (128, 128)')
            image_size = (128, 128)
            for image in image_paths:
                src = os.path.join(source_folder, image)
                dst = os.path.join(destination_folder, image)
                with Image.open(src) as img:
                    img = img.resize(image_size)
                    img.save(dst)
            logger.info(f'All Images are resized to (128, 128) and saved in {destination_folder}')
        except Exception as e:
            raise e
        
    def generate_blur_images(self) ->str:
        try:
            source_folder = self.blurimage_config.processed_image_folder
            destination_folder = self.blurimage_config.blur_image_folder
            logger.info("Generating Blur Images for Model Input")
            logger.info('Kernal Size (7, 7)')
            kernal_size = (7,7)
            for img_name in os.listdir(source_folder):
                img_path = os.path.join(source_folder, img_name)
                img = cv2.imread(img_path)
                if img is not None:
                    blurred_img = cv2.GaussianBlur(img, kernal_size, 0)
                    cv2.imwrite(os.path.join(destination_folder, img_name), blurred_img)
            logger.info(f'Generated Blur Images and saved in {destination_folder}')
        except Exception as e:
            raise e

# %%
try:
    config_maneger = ConfigurationManager()
    download_config = config_maneger.get_download_data_config()
    process_config = config_maneger.get_preprocess_data_config()
    blurimage_config = config_maneger.get_blurimage_data_config()
    downloadandprocess_data = DataIngestionPreparation(download_config, process_config, blurimage_config)

    # downloadandprocess_data.download_data()
    downloadandprocess_data.download_files_in_parallel()
    downloadandprocess_data.preprocess_data()
    downloadandprocess_data.generate_blur_images()
except Exception as e:
    raise e
# Out:
# [2024-09-24 16:33:31,695:INFO:util_functions:yaml file: ..\config\config.yaml loaded successfully]
# [2024-09-24 16:33:31,701:INFO:util_functions:yaml file: ..\params.yaml loaded successfully]
# [2024-09-24 16:33:31,703:INFO:util_functions:yaml file: ..\secret\secrets.yaml loaded successfully]
# [2024-09-24 16:33:31,705:INFO:util_functions:Created directory at : ../artifacts]
# [2024-09-24 16:33:31,706:INFO:1850321610:getting download data configuration]
# [2024-09-24 16:33:31,707:INFO:1850321610:Creating dataset and orignal_image folder Inside artifacts folder]
# [2024-09-24 16:33:31,709:INFO:util_functions:Created directory at : ../artifacts/dataset]
# [2024-09-24 16:33:31,726:INFO:util_functions:Created directory at : ../artifacts/dataset/orignal_images]
# [2024-09-24 16:33:31,728:INFO:1850321610:getting download data configuration]
# [2024-09-24 16:33:31,729:INFO:1850321610:Creating Data Directory Folder]
# [2024-09-24 16:33:31,733:INFO:util_functions:Created directory at : ../artifacts/dataset/processed_images]
# [2024-09-24 16:33:31,735:INFO:1850321610:getting download data configuration]
# [2024-09-24 16:33:31,736:INFO:1850321610:Creating Data Directory Folder]
# [2024-09-24 16:33:31,739:INFO:util_functions:Created directory at : ../artifacts/dataset/blur_images]
# [2024-09-24 16:33:32,403:INFO:2675055801:response : 200]
# Downloading...
# From: https://drive.google.com/uc?id=1e9I1ifTLkCbWlTRjxIrn6yZkJALPStPp
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009962.jpg
#   0%|          | 0.00/129k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1aGbCysBAH5gHz1qa49qnfMKOYRc2JcK-
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009612.jpg
# Downloading...
# From: https://drive.google.com/uc?id=1tVb_NswZdO_2Tu6jZvNn-rffCo7bdZqm
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009611.jpg
# Downloading...
# From: https://drive.google.com/uc?id=1KyoDPdPALmkTOVHi8rLPNAKkdZ8eHQg9
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009615.jpg
#
#
#
#   0%|          | 0.00/150k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1RL81dIreDkA2LYy0YHnJKAIH3GLfEOEQ
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009603.jpg
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1DeUfuqpEAROfnVGcqAAYJ8ttwP_hxnxX
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009618.jpg
#
#
#
#
#
#   0%|          | 0.00/149k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1gZV5WZ62kYI4BCejkP-aIdYlz_TA4zB9
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009619.jpg
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1STCQQbXJjZ1D2NX1zhNzj_Tar66aEDQT
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009961.jpg
#
#
#
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1n5_RkRMV7eH3EhfLeV_gDiQB93Pp7haR
# 100%|██████████| 129k/129k [00:00<00:00, 640kB/s]jects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009624.jpgDownloading...
# From: https://drive.google.com/uc?id=13IDsEORrb4qgxEqXPuJShT6DTwLsMdXe
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009571.jpg
# 100%|██████████| 129k/129k [00:00<00:00, 601kB/s]Downloading...
# From: https://drive.google.com/uc?id=1nWOAG4bKi_KZVj31xKsCvkCAcZ-RsOwA
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009620.jpg
#
#
#
#
#
#
#
#
#   0%|          | 0.00/117k [00:00<?, ?B/s]
#
#
#
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1wQIotm3rdH-B1UIegQiMjzszvAxTiO_c
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009623.jpg
#
#
#
#
#
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1WHXYajr9DQi6O3GAER_dn1Nrtgy2sj7u
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009960.jpg
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 127k/127k [00:00<00:00, 733kB/s]
# Downloading...
# Downloading...
# From: https://drive.google.com/uc?id=1Huhg2DCECSX6ELQX7dDq4IfxEx8JXfvT
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009614.jpg
# From: https://drive.google.com/uc?id=1ilU2WEdg6BA0R-Y20QDLmNWHxYBtO2rn
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009606.jpg
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 111k/111k [00:00<00:00, 549kB/s]
#
# 100%|██████████| 148k/148k [00:00<00:00, 575kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=179-ma_3hZcNyIuv-94pSOhwpFVtMn0en
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009613.jpg
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 150k/150k [00:00<00:00, 455kB/s]
# 100%|██████████| 114k/114k [00:00<00:00, 566kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1MA18QUyaRLj4cxJRSxCC03CKYffB4RTZ
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009610.jpg
# Downloading...
# From: https://drive.google.com/uc?id=1UqZV8Apt7WNWqlfg_r3zlnagNVzhsqG5
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009609.jpg
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1erm0uWXL36d7hrvPE5qeIbAuCqvqPMHd
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009580.jpg
# Downloading...
# From: https://drive.google.com/uc?id=15BofP_4ICYTPYkgwV9iwY5Ae01UFjROl
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009608.jpg
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 162k/162k [00:00<00:00, 590kB/s]
# 100%|██████████| 117k/117k [00:00<00:00, 423kB/s]
#
#
#
#
#
#
#
#
#   0%|          | 0.00/112k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1Bv5PNzgfqwl5cTng0TkWL6jb9gwGCIJN
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009575.jpg
#
#
#
#
#
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1UtkrQKL0LYp0r0m9yEZYzB0eBs7DHGx-
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009617.jpg
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0.00/134k [00:00<?, ?B/s]
#
#
#
# 100%|██████████| 149k/149k [00:00<00:00, 368kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1mbX6SkJqr_CG-cmG2UojaOtwJ_EizFK6
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009621.jpg
#
#
#
#
#
#
#
# 100%|██████████| 127k/127k [00:00<00:00, 277kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Y4wF5twq9_jvhuQapsb0mFUZgJkKvTBo
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009601.jpg
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1YEShGHUDcDU2aym7MdAzQ_LGLdQM3F4r
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009963.jpg
#
#
#
#
#
#
#
#
#
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1MO20HWf5mKhDkAYiFTeFvO19Ry3OQ9ro
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009602.jpg
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1DCTczF7HkQCuT5VTEpBApw07QK1jVE6y
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009616.jpg
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 119k/119k [00:00<00:00, 256kB/s]
#
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1FF9J_QaXngAOGXNrjncLCq6ooBS4Mzp-
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009622.jpg
# 100%|██████████| 96.2k/96.2k [00:00<00:00, 293kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 112k/112k [00:00<00:00, 311kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1CCI3y99eAFuC34M2AQzKBI0XXYGsXDYu
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009600.jpg
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 110k/110k [00:00<00:00, 275kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1TsfCN5Kiw4JKq-MQMYMls2pftlFNVzX7
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009607.jpg
# Downloading...
# From: https://drive.google.com/uc?id=1OJ3YMR7KEKlfEzsfMaVqOCoEd97-_Xxk
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009604.jpg
# 100%|██████████| 134k/134k [00:00<00:00, 291kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 134k/134k [00:00<00:00, 280kB/s]
# 100%|██████████| 150k/150k [00:00<00:00, 306kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 130k/130k [00:00<00:00, 321kB/s]
#
#
#
#
#
#
# 100%|██████████| 130k/130k [00:00<00:00, 137kB/s]
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 138k/138k [00:00<00:00, 152kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 168k/168k [00:00<00:00, 280kB/s]
# 100%|██████████| 136k/136k [00:00<00:00, 154kB/s]
# 100%|██████████| 169k/169k [00:00<00:00, 361kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 157k/157k [00:00<00:00, 197kB/s]
# 100%|██████████| 114k/114k [00:00<00:00, 302kB/s]
# 100%|██████████| 136k/136k [00:00<00:00, 291kB/s]
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 183k/183k [00:01<00:00, 171kB/s]
# 100%|██████████| 143k/143k [00:00<00:00, 158kB/s]
#
#
#
#
# 100%|██████████| 195k/195k [00:00<00:00, 568kB/s]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 236k/236k [00:00<00:00, 606kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 199k/199k [00:00<00:00, 225kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 167k/167k [00:00<00:00, 193kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1VDBu_smE6APllGDS1R5KJmLLVR4vvUqY
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009562.jpg
# 100%|██████████| 160k/160k [00:00<00:00, 2.06MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1fB4SEcJ8I-Lr3ClLofiPFPZ0eLa5xchY
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009590.jpg
#   0%|          | 0.00/116k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1RdgJcl3L_q6TahAtqSbl2XnQ42oFEVSe
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009593.jpg
# 100%|██████████| 186k/186k [00:00<00:00, 2.47MB/s]
# 100%|██████████| 116k/116k [00:00<00:00, 739kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1LDEs5-X4MbZqpIaEMTTezWI9gFUmKFLC
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009564.jpg
#   0%|          | 0.00/132k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1DuzI4IKNs18ZI2R1WpD-2JJFz-v0Gsiv
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009570.jpg
# Downloading...
# From: https://drive.google.com/uc?id=1Ca7HXjH6Yh_PDc88ANMJynokRS-dAcBo
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009591.jpg
#
# 100%|██████████| 132k/132k [00:00<00:00, 825kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1YmgHyjEwNIFADl4rwUsM04RLcxVRxIbh
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009588.jpg
# 100%|██████████| 132k/132k [00:00<00:00, 674kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1jl-IjbXLZdajTHQg0bMv2ldCkMdGw4l8
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009576.jpg
#
#
# 100%|██████████| 128k/128k [00:00<00:00, 647kB/s]Downloading...
# From: https://drive.google.com/uc?id=1cztEEpAnvjbJSreqP4HmnZx7wx3u5BX0
# 100%|██████████| 128k/128k [00:00<00:00, 645kB/s]jects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009566.jpg
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1IDVj2c09FU9Y4wdf-bcOXOH_v48LmqjQ
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009563.jpg
#
#
#   0%|          | 0.00/176k [00:00<?, ?B/s]Downloading...
# Downloading...
# From: https://drive.google.com/uc?id=1mJBAPFXkUAUmX6-TkvvTB9nnOwfXxz_y
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009586.jpg
# From: https://drive.google.com/uc?id=1HIacun5oWxywkfWftCy2KNPCj9jbIpW4
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009592.jpg
#
#
#
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1hjns1ijhtruSbuWyj2jpGAeHRzgjYuGf
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009573.jpg
#
#
#
#
#
# 100%|██████████| 151k/151k [00:00<00:00, 707kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12xbPZiaRssu8Ygd9-4upi8_MRc9s8cUU
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009589.jpg
# Downloading...
# From: https://drive.google.com/uc?id=1xmUtIxW520Mr1u9hjRDUXlCZ2Sq6an29
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009577.jpg
# Downloading...
# From: https://drive.google.com/uc?id=1CcdtiP2cRCbfeRbkZOXi-v4CstP0NYWF
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009581.jpg
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0.00/134k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1cUomo5fHWlmJFW77n1Dy7pR7nm_kCq_D
#   0%|          | 0.00/91.6k [00:00<?, ?B/s]ub Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009568.jpg
#
#
#
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1q1zuRU-cGu3dFDpDh-N_NFhil65uq5Mq
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009578.jpg
#
#
#
#
#
#
#
#
#
# 100%|██████████| 136k/136k [00:00<00:00, 698kB/s]
#
# 100%|██████████| 132k/132k [00:00<00:00, 698kB/s]
#
#
#
#
#
# 100%|██████████| 123k/123k [00:00<00:00, 724kB/s]Downloading...
# From: https://drive.google.com/uc?id=1WJ2ESgqhOTbUV2kSRbvIjYXCxMFe8jw_
# 100%|██████████| 123k/123k [00:00<00:00, 658kB/s]jects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009567.jpg
#
#
# 100%|██████████| 176k/176k [00:00<00:00, 766kB/s]
#
#
#
# 100%|██████████| 159k/159k [00:00<00:00, 670kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1D9SFzwRcLb4QLyse-qq6BASaAe4rde10
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009579.jpg
#
# Downloading...
# From: https://drive.google.com/uc?id=1kpuujPAwWD19-PX5dgwEF4qO-qbdStT7
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009574.jpg
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1W0K8YWSyhpBK8Gm9Br3zA_efGSmvKwF7
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009569.jpg
#
#
# 100%|██████████| 91.6k/91.6k [00:00<00:00, 404kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Q4Gin2KR92xLrgm6vI_9IyVZvfChqRDG
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009584.jpg
#   0%|          | 0.00/193k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1NeMBBrVT8hgSI2PLUTx-Fr4aeUBwlH2K
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009561.jpg
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1j8PQwwe2y7ZUZWAXsnW8XPOOiOIB-RjJ
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009595.jpg
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 117k/117k [00:00<00:00, 511kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1sPnCTzKnhyDbdJdtHCZ7xTS_KwfbKBsB
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009583.jpg
#
#
#
#
#
#
# 100%|██████████| 150k/150k [00:00<00:00, 385kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1rw_MZXSYHZCvkAxkaceI1nn5T6ANGukM
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009565.jpg
#
#
#
#
#
#
#
#   0%|          | 0.00/111k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1JuYMPLnrx7B10a4Uip_qpoRjQWooifGY
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009537.jpg
#
#
#
#
#
#
# 100%|██████████| 134k/134k [00:00<00:00, 323kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 147k/147k [00:00<00:00, 305kB/s]
#
#
#
#
#
#
#
#
#
# 100%|██████████| 117k/117k [00:00<00:00, 269kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=19d7YpM76ajKYIcwZLq9LZJ5DAOaSSkxS
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009572.jpg
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 151k/151k [00:00<00:00, 278kB/s]
#
#
# 100%|██████████| 112k/112k [00:00<00:00, 231kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=14m34V1qDsXVEvoniMl88LRN48YVXfFlh
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009585.jpg
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 147k/147k [00:00<00:00, 328kB/s]
#
#
#
#
#
#
# 100%|██████████| 111k/111k [00:00<00:00, 307kB/s]
#
#
#
# 100%|██████████| 202k/202k [00:00<00:00, 316kB/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 143k/143k [00:00<00:00, 354kB/s]
# 100%|██████████| 192k/192k [00:00<00:00, 276kB/s]
# 100%|██████████| 169k/169k [00:00<00:00, 310kB/s]
#
#
#
#
#
# 100%|██████████| 193k/193k [00:00<00:00, 314kB/s]
# 100%|██████████| 126k/126k [00:00<00:00, 308kB/s]
# 100%|██████████| 199k/199k [00:00<00:00, 382kB/s]
#
#
# 100%|██████████| 161k/161k [00:00<00:00, 709kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1hNXHzERB9eavWI6RznNAncW_GUCgVZQ2
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009587.jpg
# 100%|██████████| 100k/100k [00:00<00:00, 591kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1IELRK_Pup-LnginXtuivCiMQExoAWPnq
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009558.jpg
# 100%|██████████| 120k/120k [00:00<00:00, 768kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1A8bct5XJPohnyILgPYmg8NbP16t4ZnQt
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009542.jpg
#   0%|          | 0.00/125k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1NsPGBHCK6KtJO8vKBGh8ayeSdJqaXXjr
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009560.jpg
# 100%|██████████| 125k/125k [00:00<00:00, 1.76MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1OwPiJ7ji6Kuh6q7JCnSMV2p3GpbY4HZx
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009554.jpg
# 100%|██████████| 116k/116k [00:00<00:00, 477kB/s]
# 100%|██████████| 122k/122k [00:00<00:00, 730kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1xd9uIaH5PnPZbWu0seIwT7Hp2bOxN6OI
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009550.jpg
#   0%|          | 0.00/156k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1QbwTxKAEfhJjtzan1blFn61CfWv6pbS0
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009525.jpg
# 100%|██████████| 156k/156k [00:00<00:00, 660kB/s]
# 100%|██████████| 130k/130k [00:00<00:00, 659kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1YODrp7nCbM-KeUeWVGBR3WfUISvCC4FC
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009539.jpg
#   0%|          | 0.00/156k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1cGm30oFLJvk90XKDrhknFF7sodIQ4hol
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009546.jpg
# 100%|██████████| 156k/156k [00:00<00:00, 712kB/s]
# 100%|██████████| 171k/171k [00:00<00:00, 901kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1coAiEorjrRMYuxQP8Rc8vT0ujmQSIk1E
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009526.jpg
#   0%|          | 0.00/164k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1ZGvE_gBzR5E5_JQ5kcJo8dGXbIG3ozPl
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009552.jpg
# Downloading...
# From: https://drive.google.com/uc?id=1AkKN2GeexI4Xd0g-JuXuAnvSBJv0HBLM
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009553.jpg
#
# 100%|██████████| 164k/164k [00:00<00:00, 858kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1HIMxSZRuoc8I86CQofLNLz1NHzOIaMnd
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009557.jpg
# 100%|██████████| 165k/165k [00:00<00:00, 887kB/s]
#
# 100%|██████████| 118k/118k [00:00<00:00, 648kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1WnBXCHFlXuevYzAVnpc_cigcVmbnXU9N
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009547.jpg
# Downloading...
# From: https://drive.google.com/uc?id=1PLmetOSMktE8hsBs2CR_zr_-2_8KvdUc
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009540.jpg
#
# 100%|██████████| 158k/158k [00:00<00:00, 2.09MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1MQHpLGICR5-dONpXKiTfIfQdLA0LSj2p
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009556.jpg
#   0%|          | 0.00/150k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1D5VX3nEOkwDmLJ38uatu1t6x2CBnGmv4
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009541.jpg
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1y9XDRsgBRV0gr8aFM3wMMzRX5epItJNS
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009555.jpg
# Downloading...
# From: https://drive.google.com/uc?id=14z_qIitzK2fA67xs_Hd9TwHoElxANPDq
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009530.jpg
#
#
#
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=11ZAepq16t9Vs6e7sXJL6CfKh9qRtAthK
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009534.jpg
#
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1I73q5ZgCYCMSuxuJ7NbNvfJ5TExu3Jy6
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009548.jpg
#
#
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1VnfBCbPeNi7JKuxTb7bkKD_AT1jaiygT
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009538.jpg
#
#
#
#
#
#
#
# 100%|██████████| 115k/115k [00:00<00:00, 1.57MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1cQK2QKucLcXR_L15ilSMr77M3ksoo7Ae
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009527.jpg
#
#
#
#
#
#
#
# 100%|██████████| 186k/186k [00:00<00:00, 1.35MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1M8GX-X3TwqUlbIl5S9LfzTG6J-EnMyG8
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009536.jpg
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=15BymzH0lPf-SDaMxevKIe3FIvlxLNtff
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009551.jpg
#
#
#
#
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1fQMqeDdnFf5B47kADVs6IztH1LGpaDFf
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009532.jpg
#
#
#
#
#
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=18jBLdTFVeIb99sBRAgmZteTKY7SftU4i
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009543.jpg
#
#
#
#
#
#
#
#
#
#
#
#
# Downloading...
# From: https://drive.google.com/uc?id=1YdbIMRTR40IsBWShwgc3o6kvLFXbG23t
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009535.jpg
#
# 100%|██████████| 120k/120k [00:00<00:00, 275kB/s]
# 100%|██████████| 142k/142k [00:00<00:00, 351kB/s]
# 100%|██████████| 141k/141k [00:00<00:00, 336kB/s]
# 100%|██████████| 150k/150k [00:00<00:00, 343kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1wkfo6ZKS1aadjHbAoM1d-Q6HOcZLT2Dq
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009529.jpg
#   0%|          | 0.00/183k [00:00<?, ?B/s]
#
#
#
#
# 100%|██████████| 114k/114k [00:00<00:00, 285kB/s]
#
#
#
#
#
#
# 100%|██████████| 115k/115k [00:00<00:00, 284kB/s]
#
#
#
#
#
#
#
#
# 100%|██████████| 89.4k/89.4k [00:00<00:00, 254kB/s]
#
#
#
#
#
#
#
# 100%|██████████| 143k/143k [00:00<00:00, 298kB/s]
#
#
#
#
# 100%|██████████| 127k/127k [00:00<00:00, 289kB/s]
#
#
#
# 100%|██████████| 214k/214k [00:00<00:00, 422kB/s]
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 193k/193k [00:00<00:00, 544kB/s]
#
#
#
#
#
#
#
#
#
# 100%|██████████| 195k/195k [00:00<00:00, 464kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1QrjuDPFS1D62dR-12UidNz9-jED46gW8
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009533.jpg
#
# 100%|██████████| 164k/164k [00:00<00:00, 619kB/s]
# 100%|██████████| 183k/183k [00:00<00:00, 723kB/s]
#
# 100%|██████████| 167k/167k [00:00<00:00, 815kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ve3_BmU6ydYFRN20NYbWrSFz6k6SwUOY
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009528.jpg
# 100%|██████████| 134k/134k [00:00<00:00, 751kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1us4rAph5NiUHI_QNyT8GDqqokBhNhMRG
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009545.jpg
# 100%|██████████| 158k/158k [00:00<00:00, 2.57MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1B20E2BEl0pc9dkLonJrfVrjxrGq_TZsF
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009531.jpg
#   0%|          | 0.00/154k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1Nt5g_fJcKZBwSJHd0aHHB-KnoKah_M3U
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009544.jpg
# 100%|██████████| 154k/154k [00:00<00:00, 696kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1EixFBaIz59Zb6hZNxSrrHGITqlOxeDWc
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009559.jpg
#   0%|          | 0.00/175k [00:00<?, ?B/s]Downloading...
# From: https://drive.google.com/uc?id=1YbYBjLVK05kwp3yabNyjACS-l6TBHpaO
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009549.jpg
#
# 100%|██████████| 129k/129k [00:00<00:00, 620kB/s]
# 100%|██████████| 175k/175k [00:00<00:00, 916kB/s]
#
# 100%|██████████| 130k/130k [00:00<00:00, 614kB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1fS5volaqXTdmCDxlPBlentp8fWt9ghv4
# From (redirected): https://drive.google.com/uc?id=1fS5volaqXTdmCDxlPBlentp8fWt9ghv4&confirm=t&uuid=95f77a9e-398e-469e-bc21-02bc6405a577
# To: d:\SONU\folder c\Desktop\Portfolio Github Projects\Deblur-Image-autoencoder\artifacts\dataset\orignal_images\SFHQ_pt2_00009605.jpg
# 100%|██████████| 112k/112k [00:00<00:00, 704kB/s]
